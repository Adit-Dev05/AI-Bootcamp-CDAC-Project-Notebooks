# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/Colab Notebooks/AI - BootCamp -  Assignment - CCE/product_reviews.csv"

for enc in ["utf-8", "latin1", "cp1252", "ISO-8859-1"]:
    try:
        df = pd.read_csv(file_path, encoding=enc)
        print(f"Loaded with encoding: {enc}")
        break
    except UnicodeDecodeError:
        continue

print(df.head(3))
print(df.columns.tolist())
# Out:
# Loaded with encoding: latin1
#    Review_ID                                        Review_Text
# 0          1  "The product is GREAT! Loved it, but its a bi...
# 1          2  "Worst product ever!! Wouldnt recommend to an...
# 2          3  "Satisfactory quality, works as expected, no m...
# ['Review_ID', 'Review_Text']

# %%
candidates = [c for c in df.columns if c.lower() in {
    "review","reviews","review_text","text","comment","comments","content","body","feedback","reviewtext"
}]
if candidates:
    REVIEW_COL = candidates[0]
else:
    REVIEW_COL = df.select_dtypes(include=["object"]).columns[0]

print("Using review column:", REVIEW_COL)
# Out:
# Using review column: Review_Text

# %%
import re

df[REVIEW_COL] = df[REVIEW_COL].astype(str).fillna("")
df["lower"] = df[REVIEW_COL].str.lower()

# %%
def clean_text(s):
    s = re.sub(r"[^a-z\s]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

df["clean"] = df["lower"].apply(clean_text)
df[["lower","clean"]].head(3)
# Out:
#                                                lower  \
# 0  "the product is great! loved it, but its a bi...
# 1  "worst product ever!! wouldnt recommend to an...
# 2  "satisfactory quality, works as expected, no m...
#
#                                                clean
# 0  the product is great loved it but it s a bit p...
# 1    worst product ever wouldn t recommend to anyone
# 2  satisfactory quality works as expected no majo...

# %%
import nltk
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))

df["tokens"] = df["clean"].apply(word_tokenize)
df["tokens_nostop"] = df["tokens"].apply(lambda toks: [w for w in toks if w not in stop_words])

df[["tokens","tokens_nostop"]].head(3)
# Out:
#                                               tokens  \
# 0  [the, product, is, great, loved, it, but, it, ...
# 1  [worst, product, ever, wouldn, t, recommend, t...
# 2  [satisfactory, quality, works, as, expected, n...
#
#                                        tokens_nostop
# 0               [product, great, loved, bit, pricey]
# 1          [worst, product, ever, recommend, anyone]
# 2  [satisfactory, quality, works, expected, major...

# %%
nltk.download("wordnet")
nltk.download("omw-1.4")

from nltk.stem import PorterStemmer, WordNetLemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
df["stemmed"] = df["tokens_nostop"].apply(lambda toks: [stemmer.stem(w) for w in toks])
df["lemmatized"] = df["tokens_nostop"].apply(lambda toks: [lemmatizer.lemmatize(w) for w in toks])
df
# Out:
#     Review_ID                                        Review_Text  \
# 0           1  "The product is GREAT! Loved it, but its a bi...
# 1           2  "Worst product ever!! Wouldnt recommend to an...
# 2           3  "Satisfactory quality, works as expected, no m...
# 3           4  "Amazing product, I would buy it again and aga...
# 4           5  "The delivery was slow, but the product is good."
# 5           6  "Horrible experience, the product broke after ...
# 6           7  "Great value for the price! Definitely worth b...
# 7           8  "The product didnt meet my expectations, retu...
# 8           9  "Im satisfied with the purchase, but there ar...
# 9          10  "Superb product! Excellent build quality and g...
# 10         11  "The product is just okay, nothing special, bu...
# 11         12  "Fast delivery and product as described. Would...
# 12         13  "Not worth the money. The product feels cheap ...
# 13         14  "The product exceeded my expectations. Fantast...
# 14         15  "Terrible customer service, but the product it...
# 15         16  "Very happy with the product. Would definitely...
# 16         17  "Good product, but Ive had better ones for th...
# 17         18  "I received a defective item, had to return it...
# 18         19  "The product is excellent, but shipping took l...
# 19         20  "Love the product! Works as advertised and wor...
#
#                                                 lower  \
# 0   "the product is great! loved it, but its a bi...
# 1   "worst product ever!! wouldnt recommend to an...
# 2   "satisfactory quality, works as expected, no m...
# 3   "amazing product, i would buy it again and aga...
# 4   "the delivery was slow, but the product is good."
# 5   "horrible experience, the product broke after ...
# 6   "great value for the price! definitely worth b...
# 7   "the product didnt meet my expectations, retu...
# 8   "im satisfied with the purchase, but there ar...
# 9   "superb product! excellent build quality and g...
# 10  "the product is just okay, nothing special, bu...
# 11  "fast delivery and product as described. would...
# 12  "not worth the money. the product feels cheap ...
# 13  "the product exceeded my expectations. fantast...
# 14  "terrible customer service, but the product it...
# 15  "very happy with the product. would definitely...
# 16  "good product, but ive had better ones for th...
# 17  "i received a defective item, had to return it...
# 18  "the product is excellent, but shipping took l...
# 19  "love the product! works as advertised and wor...
#
#                                                 clean  \
# 0   the product is great loved it but it s a bit p...
# 1     worst product ever wouldn t recommend to anyone
# 2   satisfactory quality works as expected no majo...
# 3      amazing product i would buy it again and again
# 4       the delivery was slow but the product is good
# 5   horrible experience the product broke after ju...
# 6   great value for the price definitely worth buying
# 7   the product didn t meet my expectations return...
# 8   i m satisfied with the purchase but there are ...
# 9   superb product excellent build quality and gre...
# 10  the product is just okay nothing special but i...
# 11  fast delivery and product as described would b...
# 12  not worth the money the product feels cheap an...
# 13  the product exceeded my expectations fantastic...
# 14  terrible customer service but the product itse...
# 15  very happy with the product would definitely r...
# 16  good product but i ve had better ones for the ...
# 17  i received a defective item had to return it v...
# 18  the product is excellent but shipping took lon...
# 19  love the product works as advertised and worth...
#
#                                                tokens  \
# 0   [the, product, is, great, loved, it, but, it, ...
# 1   [worst, product, ever, wouldn, t, recommend, t...
# 2   [satisfactory, quality, works, as, expected, n...
# 3   [amazing, product, i, would, buy, it, again, a...
# 4   [the, delivery, was, slow, but, the, product, ...
# 5   [horrible, experience, the, product, broke, af...
# 6   [great, value, for, the, price, definitely, wo...
# 7   [the, product, didn, t, meet, my, expectations...
# 8   [i, m, satisfied, with, the, purchase, but, th...
# 9   [superb, product, excellent, build, quality, a...
# 10  [the, product, is, just, okay, nothing, specia...
# 11  [fast, delivery, and, product, as, described, ...
# 12  [not, worth, the, money, the, product, feels, ...
# 13  [the, product, exceeded, my, expectations, fan...
# 14  [terrible, customer, service, but, the, produc...
# 15  [very, happy, with, the, product, would, defin...
# 16  [good, product, but, i, ve, had, better, ones,...
# 17  [i, received, a, defective, item, had, to, ret...
# 18  [the, product, is, excellent, but, shipping, t...
# 19  [love, the, product, works, as, advertised, an...
#
#                                         tokens_nostop  \
# 0                [product, great, loved, bit, pricey]
# 1           [worst, product, ever, recommend, anyone]
# 2   [satisfactory, quality, works, expected, major...
# 3                      [amazing, product, would, buy]
# 4                     [delivery, slow, product, good]
# 5    [horrible, experience, product, broke, one, use]
# 6    [great, value, price, definitely, worth, buying]
# 7            [product, meet, expectations, returning]
# 8   [satisfied, purchase, better, options, available]
# 9   [superb, product, excellent, build, quality, g...
# 10  [product, okay, nothing, special, gets, job, d...
# 11   [fast, delivery, product, described, would, buy]
# 12      [worth, money, product, feels, cheap, flimsy]
# 13  [product, exceeded, expectations, fantastic, p...
# 14     [terrible, customer, service, product, decent]
# 15  [happy, product, would, definitely, recommend,...
# 16               [good, product, better, ones, price]
# 17  [received, defective, item, return, disappoint...
# 18  [product, excellent, shipping, took, longer, e...
# 19  [love, product, works, advertised, worth, ever...
#
#                                               stemmed  \
# 0                 [product, great, love, bit, pricey]
# 1            [worst, product, ever, recommend, anyon]
# 2   [satisfactori, qualiti, work, expect, major, i...
# 3                         [amaz, product, would, buy]
# 4                     [deliveri, slow, product, good]
# 5         [horribl, experi, product, broke, one, use]
# 6           [great, valu, price, definit, worth, buy]
# 7                     [product, meet, expect, return]
# 8           [satisfi, purchas, better, option, avail]
# 9   [superb, product, excel, build, qualiti, great...
# 10     [product, okay, noth, special, get, job, done]
# 11     [fast, deliveri, product, describ, would, buy]
# 12       [worth, money, product, feel, cheap, flimsi]
# 13        [product, exceed, expect, fantast, perform]
# 14         [terribl, custom, servic, product, decent]
# 15  [happi, product, would, definit, recommend, ot...
# 16                [good, product, better, one, price]
# 17         [receiv, defect, item, return, disappoint]
# 18       [product, excel, ship, took, longer, expect]
# 19  [love, product, work, advertis, worth, everi, ...
#
#                                            lemmatized
# 0                [product, great, loved, bit, pricey]
# 1           [worst, product, ever, recommend, anyone]
# 2   [satisfactory, quality, work, expected, major,...
# 3                      [amazing, product, would, buy]
# 4                     [delivery, slow, product, good]
# 5    [horrible, experience, product, broke, one, use]
# 6    [great, value, price, definitely, worth, buying]
# 7             [product, meet, expectation, returning]
# 8    [satisfied, purchase, better, option, available]
# 9   [superb, product, excellent, build, quality, g...
# 10  [product, okay, nothing, special, get, job, done]
# 11   [fast, delivery, product, described, would, buy]
# 12       [worth, money, product, feel, cheap, flimsy]
# 13  [product, exceeded, expectation, fantastic, pe...
# 14     [terrible, customer, service, product, decent]
# 15  [happy, product, would, definitely, recommend,...
# 16                [good, product, better, one, price]
# 17  [received, defective, item, return, disappoint...
# 18  [product, excellent, shipping, took, longer, e...
# 19  [love, product, work, advertised, worth, every...
